# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#funcion absoluta
def f(x):
    return np.abs(x)
n = 1000

x = np.linspace(-10, 10, 100)
y = f(x)
plt.plot(x, y)
plt.grid()

# %%
#funcion exponencial
#Se grafican funciones exponenciales con 0 < a < 1

def f(x):
    return np.exp(3**x)
def f_1(z):
    return np.exp((1/3)**x)

x = np.linspace(-10, 10, num=1000)
y1, y2 = f(x), f_1(x)
plt.plot(x, y1)
plt.plot(x, y2)
plt.grid()
# Out:
# C:\Users\rexcu\AppData\Local\Temp/ipykernel_3308/3809934240.py:5: RuntimeWarning: overflow encountered in exp
#   return np.exp(3**x)
# C:\Users\rexcu\AppData\Local\Temp/ipykernel_3308/3809934240.py:7: RuntimeWarning: overflow encountered in exp
#   return np.exp((1/3)**x)

# %%
def funciion_exp(x): 
  y = 3**x 
  ax.plot(x,y)

def funciion_exp_1(x):
  y = (1/3)**x 
  ax.plot(x,y)

x = np.linspace(-3,3,num=70)
fig, ax = plt.subplots() #se crea una figura y una gráfica
fig.set_size_inches(7,7) #Ajusto la imagen de salida
funciion_exp(x)
funciion_exp_1(x)
plt.grid()

# %%
def funciion_exp(x): 
  y = 2**x 
  ax.plot(x,y)

def funciion_exp_1(x):
  y = x**2
  ax.plot(x,y)
x = np.linspace(-3,3,num=100)

fig, ax = plt.subplots() #se crea una figura y una gráfica
fig.set_size_inches(7,7) #Ajusto la imagen de salida
funciion_exp(x)
ax.plot(y)
plt.xlim(0,3)
plt.ylim(0,8)
funciion_exp(x)
funciion_exp_1(x)
plt.legend(['2^x','x^2'])
plt.grid()

# %%
def funciion_exp(x): 
  y = 2**x 
  ax.plot(x,y)

def funciion_exp_1(x):
  y = -2**x 
  ax.plot(x,y)

x = np.linspace(-3,3,num=70)

fig, ax = plt.subplots() #se crea una figura y una gráfica
fig.set_size_inches(7,7) #Ajusto la imagen de salida
funciion_exp(x)
funciion_exp_1(x)
plt.grid()

# %%
def funciion_exp(x): 
  y = 1+2**x 
  ax.plot(x,y)

def funciion_exp_1(x):
  y = 2**x 
  ax.plot(x,y)

x = np.linspace(-3,3,num=70)

fig, ax = plt.subplots() #se crea una figura y una gráfica
fig.set_size_inches(7,7) #Ajusto la imagen de salida
funciion_exp(x)
funciion_exp_1(x)
plt.legend(['1+2^x','2^x'])
plt.grid()

# %%
def funciion_exp(x): 
  y = x**2 
  ax.plot(x,y)

def funciion_exp_1(x):
  y = 2**x 
  ax.plot(x,y)

x = np.linspace(0,3,num=100)
y = np.linspace(0,8,num=100)
fig, ax = plt.subplots() #se crea una figura y una gráfica


funciion_exp(x)
funciion_exp_1(x)
plt.legend(['x^2','2^x'])
plt.grid()
